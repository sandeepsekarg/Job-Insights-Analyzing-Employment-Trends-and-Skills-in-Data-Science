# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepsekarg/Job-Insights-Analyzing-Employment-Trends-and-Skills-in-Data-Science/blob/main/Job_Insights_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing required libraries

# %%
import pandas as pd
import nltk

# %% [markdown]
# #Read the dataset

# %%
data = pd.read_csv("/content/Uncleaned_DS_jobs.csv")

# %%
data
# Out:
#      index          Job Title               Salary Estimate  \
# 0        0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1        1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2        2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3        3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4        4     Data Scientist  $137K-$171K (Glassdoor est.)
# ..     ...                ...                           ...
# 667    667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668    668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669    669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670    670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671    671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  \
# 0    Description\n\nThe Senior Data Scientist is re...
# 1    Secure our Nation, Ignite your Future\n\nJoin ...
# 2    Overview\n\n\nAnalysis Group is one of the lar...
# ...

# %% [markdown]
# #Look into the data

# %%
data.isnull()
# Out:
#      index  Job Title  Salary Estimate  Job Description  Company Name  \
# 0    False      False            False            False         False
# 1    False      False            False            False         False
# 2    False      False            False            False         False
# 3    False      False            False            False         False
# 4    False      False            False            False         False
# ..     ...        ...              ...              ...           ...
# 667  False      False            False            False         False
# 668  False      False            False            False         False
# 669  False      False            False            False         False
# 670  False      False            False            False         False
# 671  False      False            False            False         False
#
#      Location  Headquarters   Size  Founded  Type of ownership  Industry  \
# ...

# %%
data.dtypes
# Out:
# index                 int64
# Job Title            object
# Salary Estimate      object
# Job Description      object
# Company Name         object
# Location             object
# Headquarters         object
# Size                 object
# Founded               int64
# Type of ownership    object
# Industry             object
# Sector               object
# Revenue              object
# Competitors          object
# dtype: object

# %%
data.shape
# Out:
# (672, 14)

# %%
data.isin(['-1',-1]).sum()
# Out:
# index                  0
# Job Title              0
# Salary Estimate        0
# Job Description        0
# Company Name           0
# Location               0
# Headquarters          31
# Size                  27
# Founded              118
# Type of ownership     27
# Industry              71
# Sector                71
# Revenue               27
# Competitors          501
# dtype: int64

# %%
data
# Out:
#      index          Job Title               Salary Estimate  \
# 0        0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1        1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2        2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3        3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4        4     Data Scientist  $137K-$171K (Glassdoor est.)
# ..     ...                ...                           ...
# 667    667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668    668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669    669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670    670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671    671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  \
# 0    Description\n\nThe Senior Data Scientist is re...
# 1    Secure our Nation, Ignite your Future\n\nJoin ...
# 2    Overview\n\n\nAnalysis Group is one of the lar...
# ...

# %%
data['Salary Estimate'].str.split(' ', expand = True)
# Out:
#                0           1      2
# 0    $137K-$171K  (Glassdoor  est.)
# 1    $137K-$171K  (Glassdoor  est.)
# 2    $137K-$171K  (Glassdoor  est.)
# 3    $137K-$171K  (Glassdoor  est.)
# 4    $137K-$171K  (Glassdoor  est.)
# ..           ...         ...    ...
# 667  $105K-$167K  (Glassdoor  est.)
# 668  $105K-$167K  (Glassdoor  est.)
# 669  $105K-$167K  (Glassdoor  est.)
# 670  $105K-$167K  (Glassdoor  est.)
# 671  $105K-$167K  (Glassdoor  est.)
#
# [672 rows x 3 columns]

# %%
data[['Salary range', 'Salary Revealer', 'est']] = data['Salary Estimate'].str.split(' ', expand = True)

# %%
data['Salary Revealer'] = data['Salary Revealer'].str.replace(r'\W',"")
# Out:
# <ipython-input-11-fd056ee2f1c0>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Salary Revealer'] = data['Salary Revealer'].str.replace(r'\W',"")

# %%
data = data.drop(['est', 'Salary Estimate'], axis = 1)

# %%
data['Salary range'].str.split('-', expand = True)
# Out:
#          0      1
# 0    $137K  $171K
# 1    $137K  $171K
# 2    $137K  $171K
# 3    $137K  $171K
# 4    $137K  $171K
# ..     ...    ...
# 667  $105K  $167K
# 668  $105K  $167K
# 669  $105K  $167K
# 670  $105K  $167K
# 671  $105K  $167K
#
# [672 rows x 2 columns]

# %%
data[['min salary', 'max salary']] = data['Salary range'].str.split('-', expand = True)

# %%
data
# Out:
#      index          Job Title  \
# 0        0  Sr Data Scientist
# 1        1     Data Scientist
# 2        2     Data Scientist
# 3        3     Data Scientist
# 4        4     Data Scientist
# ..     ...                ...
# 667    667     Data Scientist
# 668    668     Data Scientist
# 669    669     Data Scientist
# 670    670     Data Scientist
# 671    671     Data Scientist
#
#                                        Job Description  \
# 0    Description\n\nThe Senior Data Scientist is re...
# 1    Secure our Nation, Ignite your Future\n\nJoin ...
# 2    Overview\n\n\nAnalysis Group is one of the lar...
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4    Data Scientist\nAffinity Solutions / Marketing...
# ..                                                 ...
# 667  Summary\n\nWe’re looking for a data scientist ...
# 668  Job Description\nBecome a thought leader withi...
# 669  Join a thriving company that is changing the w...
# ...

# %%
data['min salary'] = data['min salary'].str.replace(r'K',"000")

# %%
data['max salary'] = data['max salary'].str.replace(r'K',"000")

# %%
data[['min salary', 'max salary']] = data[['min salary', 'max salary']].replace(r'\W',"")

# %%
data.dtypes
# Out:
# index                 int64
# Job Title            object
# Job Description      object
# Company Name         object
# Location             object
# Headquarters         object
# Size                 object
# Founded               int64
# Type of ownership    object
# Industry             object
# Sector               object
# Revenue              object
# Competitors          object
# Salary range         object
# Salary Revealer      object
# min salary           object
# max salary           object
# dtype: object

# %%
data.to_csv('new_data.csv', index = False)

# %%
data = data.drop('index', axis = 1)

# %%
data['max salary'].str.replace(r'\W',"")
# Out:
# <ipython-input-21-dc9166e1643f>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['max salary'].str.replace(r'\W',"")
# 0      171000
# 1      171000
# 2      171000
# 3      171000
# 4      171000
#         ...
# 667    167000
# 668    167000
# 669    167000
# 670    167000
# 671    167000
# Name: max salary, Length: 672, dtype: object

# %%
data['max salary'] = data['max salary'].str.replace(r'\W',"")
# Out:
# <ipython-input-22-e466980710d1>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['max salary'] = data['max salary'].str.replace(r'\W',"")

# %%
data['min salary'].str.replace(r'\W',"")
# Out:
# <ipython-input-23-3af639c2620f>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['min salary'].str.replace(r'\W',"")
# 0      137000
# 1      137000
# 2      137000
# 3      137000
# 4      137000
#         ...
# 667    105000
# 668    105000
# 669    105000
# 670    105000
# 671    105000
# Name: min salary, Length: 672, dtype: object

# %%
data['min salary'] = data['min salary'].str.replace(r'\W',"")
# Out:
# <ipython-input-24-3007c66ce504>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['min salary'] = data['min salary'].str.replace(r'\W',"")

# %%
data.head()
# Out:
#            Job Title                                    Job Description  \
# 0  Sr Data Scientist  Description\n\nThe Senior Data Scientist is re...
# 1     Data Scientist  Secure our Nation, Ignite your Future\n\nJoin ...
# 2     Data Scientist  Overview\n\n\nAnalysis Group is one of the lar...
# 3     Data Scientist  JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4     Data Scientist  Data Scientist\nAffinity Solutions / Marketing...
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# 3             INFICON\n3.5     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions\n2.9   New York, NY            New York, NY
#
#                       Size  Founded        Type of ownership  \
# 0   1001 to 5000 employees     1993   Nonprofit Organization
# ...

# %%
data.dtypes
# Out:
# Job Title            object
# Job Description      object
# Company Name         object
# Location             object
# Headquarters         object
# Size                 object
# Founded               int64
# Type of ownership    object
# Industry             object
# Sector               object
# Revenue              object
# Competitors          object
# Salary range         object
# Salary Revealer      object
# min salary           object
# max salary           object
# dtype: object

# %%
data.to_csv('new_data.csv', index = False)

# %%
data['Salary range'].str.split('(', expand = True)
# Out:
#                0     1
# 0    $137K-$171K  None
# 1    $137K-$171K  None
# 2    $137K-$171K  None
# 3    $137K-$171K  None
# 4    $137K-$171K  None
# ..           ...   ...
# 667  $105K-$167K  None
# 668  $105K-$167K  None
# 669  $105K-$167K  None
# 670  $105K-$167K  None
# 671  $105K-$167K  None
#
# [672 rows x 2 columns]

# %%
data[['salary_range', 'salary revealer']] = data['Salary range'].str.split('(', expand = True)

# %%
data['Salary_Revealer'] = data['Salary Revealer'] + data['salary revealer']

# %%
data
# Out:
#              Job Title                                    Job Description  \
# 0    Sr Data Scientist  Description\n\nThe Senior Data Scientist is re...
# 1       Data Scientist  Secure our Nation, Ignite your Future\n\nJoin ...
# 2       Data Scientist  Overview\n\n\nAnalysis Group is one of the lar...
# 3       Data Scientist  JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4       Data Scientist  Data Scientist\nAffinity Solutions / Marketing...
# ..                 ...                                                ...
# 667     Data Scientist  Summary\n\nWe’re looking for a data scientist ...
# 668     Data Scientist  Job Description\nBecome a thought leader withi...
# 669     Data Scientist  Join a thriving company that is changing the w...
# 670     Data Scientist  100 Remote Opportunity As an AINLP Data Scient...
# 671     Data Scientist  Description\n\nThe Data Scientist will be part...
#
#                   Company Name           Location            Headquarters  \
# ...
